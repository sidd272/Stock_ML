# %%
import pandas as pd
import numpy as np

# %%
def sma(series,Period):
    return series.rolling(Period).mean()

# %%
def wma(series,Period):
    weights = np.ones(Period) / Period
    return np.convolve(series, weights, mode='same')

# %%
def ema(series, Period):
    alpha=2 / (Period + 1)
    w = np.empty(len(series))
    w[0] = 1
    for i in range(1, len(series)):
        w[i] = w[i - 1] * (1 - alpha) + alpha * series[i]
    return w

# %%
def vwma(series,Period):
    tpv = np.cumprod(series * close, axis=0)
    cum_volume = np.cumsum(series, axis=0)
    vwma = tpv / cum_volume
    return vwma

# %%
def rma(series,Period):
    rma = series.ewm(span=Period, min_periods=Period - 1).mean()
    return rma

# %%
def change(open, high, low, close, period):
    return close - close[period - 1]

# %%
def tr(open,high,low,close):
    return max(high-low,abs(high-close[1]),abs(low-close[1]))

# %%
def ATR(high, low, close, period):
    tr = pd.DataFrame({'high': high, 'low': low, 'close': close})
    tr['tr1'] = tr['high'] - tr['low']
    tr['tr2'] = abs(tr['high'] - tr['close'].shift(1))
    tr['tr3'] = abs(tr['low'] - tr['close'].shift(1))
    
    tr['true_range'] = tr[['tr1', 'tr2', 'tr3']].max(axis=1)
    atr = tr['true_range'].rolling(window=period).mean()
    return atr

# %%
def nz(x, y=None):
    if isinstance(x, np.generic):
        return x.fillna(y or 0)
    if x != x:
        if y is not None:
            return y
        return 0
    return x

# %%
def NSDT(Open, high, low, close):
    ma_type = "WMA"
    ma_source = close
    ma_length = 55
    stepn = 5
    ma = wma(close, 55)

    OpenLength = 25
    OpenType = "EMA"
    HighLength = 20
    HighType = "EMA"
    LowLength = 20
    LowType = "EMA"
    CloseLength = 20
    CloseType = "EMA"
    LengthMA = 55
    MAType = "EMA"
    MASource = (high + low) / 2

    TypeOpen = OpenType
    SourceOpen = (Open[-1] + close[-1]) / 2
    LengthOpen = OpenLength

    TypeHigh = HighType
    SourceHigh = np.maximum(high, close)
    LengthHigh = HighLength

    TypeLow = LowType
    SourceLow = np.minimum(low, close)
    LengthLow = LowLength

    TypeClose = CloseType
    SourceClose = (open + high + low + close) / 4
    LengthClose = CloseLength

    def funcCalc(type1, src1, len1):
        return_1 = ema(src1, len1) if type1 == 'EMA' else sma(src1, len1) if type1 == 'SMA' else wma(src1, len1) if type1 == 'WMA' else None
        return return_1

    def funcCalcOpen(TypeOpen, SourceOpen, LengthOpen):
        return_2 = ema(SourceOpen, LengthOpen) if TypeOpen == 'EMA' else sma(SourceOpen, LengthOpen) if TypeOpen == 'SMA' else wma(SourceOpen, LengthOpen) if TypeOpen == 'WMA' else None
        return return_2

    def funcCalcHigh(TypeHigh, SourceHigh, LengthHigh):
        return_3 = ema(SourceHigh, LengthHigh) if TypeHigh == 'EMA' else sma(SourceHigh, LengthHigh) if TypeHigh == 'SMA' else wma(SourceHigh, LengthHigh) if TypeHigh == 'WMA' else None
        return return_3

    def funcCalcLow(TypeLow, SourceLow, LengthLow):
        return_4 = ema(SourceLow, LengthLow) if TypeLow == 'EMA' else sma(SourceLow, LengthLow) if TypeLow == 'SMA' else wma(SourceLow, LengthLow) if TypeLow == 'WMA' else None
        return return_4

    def funcCalcClose(TypeClose, SourceClose, LengthClose):
        return_5 = ema(SourceClose, LengthClose) if TypeClose == 'EMA' else sma(SourceClose, LengthClose) if TypeClose == 'SMA' else wma(SourceClose, LengthClose) if TypeClose == 'WMA' else None
        return return_5

    MA1 = funcCalc(MAType, MASource, LengthMA)

    CandleOpen = funcCalcOpen(TypeOpen, SourceOpen, LengthOpen)
    CandleHigh = funcCalcHigh(TypeHigh, SourceHigh, LengthHigh)
    CandleLow = funcCalcLow(TypeLow, SourceLow, LengthLow)
    CandleClose = funcCalcClose(TypeClose, SourceClose, LengthClose)

# %%
def Supertrend(data, periods=10, multiplier=3.0):
    src = (data['High'] + data['Low']) / 2
    atr2 = sma(data['TR'], periods)
    
    def nz(x, y):
        return np.where(pd.isna(x), y, x)
    
    up = src - (multiplier * atr2)
    up1 = nz(pd.Series(up).shift(1), up)
    up = np.where(data['Close'].shift(1) > up1, up, up1)
    
    dn = src + (multiplier * atr2)
    dn1 = nz(pd.Series(dn).shift(1), dn)
    dn = np.where(data['Close'].shift(1) < dn1, dn, dn1)
    
    trend = np.ones(len(data))  # Initialize as an array of ones
    for i in range(1, len(data)):
        trend[i] = trend[i - 1]
        if trend[i] == 1:
            if data['Close'][i] < up1[i]:
                trend[i] = -1
        else:
            if data['Close'][i] > dn1[i]:
                trend[i] = 1
    
    buySignal = (pd.Series(trend) == 1) & (pd.Series(trend).shift(1) == -1)
    sellSignal = (pd.Series(trend) == -1) & (pd.Series(trend).shift(1) == 1)
    
    return trend, buySignal, sellSignal

# %%
def MACD(close):
    fast_length = 12
    slow_length = 26
    src = close
    signal_length = 9
    sma_source = "EMA"
    sma_signal = "EMA"
    fast_ma = ema(src, fast_length)
    slow_ma =  ema(src, slow_length)
    macd = fast_ma - slow_ma
    signal = ema(macd, signal_length)
    hist = macd - signal
    return [macd,signal,hist]

# %%
def rsi():
    rsiLengthInput = 14
    rsiSourceInput = close
    maTypeInput = "SMA"
    maLengthInput = 14
    bbMultInput = 2.0
    up = rma(max(change(rsiSourceInput), 0), rsiLengthInput)
    down = rma(-min(change(rsiSourceInput), 0), rsiLengthInput)
    rsi = 100 if down == 0 else  0 if up == 0 else 100 - (100 / (1 + up / down))
    return rsi

# %%
def OpenCloseCross(data, delayOffset=0, basisType="SMA", basisLen=8):
    closeSeries = sma(data['Close'].shift(delayOffset), basisLen)
    openSeries = sma(data['Open'].shift(delayOffset), basisLen)
    xlong = data['Close'] > openSeries
    xshort = data['Close'] < openSeries
    return xlong, xshort

# %%
def CenterOfLinearity(data, length=14):
    src = data['Close']
    a = 0
    for i in range(1, length + 1):
        a = a + i * (src.iloc[length - i] - src.iloc[i - 1])
    return a

# %%
def ADX_DI(data, period=14, threshold=20):
    data['TrueRange'] = data['High'] - data['Low']
    data['High_Close'] = abs(data['High'] - data['Close'].shift(1))
    data['Low_Close'] = abs(data['Low'] - data['Close'].shift(1))

    data['TrueRange'] = data[['TrueRange', 'High_Close', 'Low_Close']].max(axis=1)

    data['DirectionalMovementPlus'] = (data['High'] - data['High'].shift(1)).clip(lower=0).fillna(0)
    data['DirectionalMovementMinus'] = (data['Low'].shift(1) - data['Low']).clip(lower=0).fillna(0)

    data['SmoothedTrueRange'] = data['TrueRange'].rolling(window=period).mean()
    data['SmoothedDirectionalMovementPlus'] = data['DirectionalMovementPlus'].rolling(window=period).mean()
    data['SmoothedDirectionalMovementMinus'] = data['DirectionalMovementMinus'].rolling(window=period).mean()

    data['DIPlus'] = (data['SmoothedDirectionalMovementPlus'] / data['SmoothedTrueRange']) * 100
    data['DIMinus'] = (data['SmoothedDirectionalMovementMinus'] / data['SmoothedTrueRange']) * 100

    data['DX'] = (abs(data['DIPlus'] - data['DIMinus']) / (data['DIPlus'] + data['DIMinus'])) * 100
    data['ADX'] = data['DX'].rolling(window=period).mean()

    return data['ADX']

# %%
data=pd.read_csv('../NIFTY_data/NIFTY_2020.csv')

# %%
data
# Out:
#       Instrument      Date   Time      Open      High       Low     Close
# 0          NIFTY  20200101  09:08  12202.15  12202.15  12202.15  12202.15
# 1          NIFTY  20200101  09:16  12204.45  12216.25  12201.55  12215.10
# 2          NIFTY  20200101  09:17  12215.45  12216.45  12205.70  12206.80
# 3          NIFTY  20200101  09:18  12206.50  12207.40  12202.70  12202.70
# 4          NIFTY  20200101  09:19  12203.55  12208.40  12201.20  12207.85
# ...          ...       ...    ...       ...       ...       ...       ...
# 94879      NIFTY  20201231  15:28  13977.90  13981.55  13977.90  13978.45
# 94880      NIFTY  20201231  15:29  13980.20  13980.45  13966.20  13967.40
# 94881      NIFTY  20201231  15:30  13968.65  13971.10  13965.20  13967.00
# 94882      NIFTY  20201231  15:31  13967.20  13967.20  13967.20  13967.20
# 94883      NIFTY  20201231  15:32  13981.75  13981.75  13981.75  13981.75
#
# [94884 rows x 7 columns]

# %%
data['TR'] = ATR(data['High'], data['Low'], data['Close'], 14)
data['SMA5'] = sma(data['Close'], 5)
data['RMA5'] = rma(data['Close'], 5)
data['WMA5'] = wma(data['Close'], 5)
data['signal'] = MACD(data['Close'])[0]
data['macd'] = MACD(data['Close'])[1]
data['hist'] = MACD(data['Close'])[2]
data['ADX'] = ADX_DI(data)
data['CenterOfLinearity'] = CenterOfLinearity(data)
data['LongSignal'], data['ShortSignal'] = OpenCloseCross(data)
data['Supertrend'], data['BuySignal'], data['SellSignal'] = Supertrend(data)

# %%
data
# Out:
#       Instrument      Date   Time      Open      High       Low     Close  \
# 0          NIFTY  20200101  09:08  12202.15  12202.15  12202.15  12202.15
# 1          NIFTY  20200101  09:16  12204.45  12216.25  12201.55  12215.10
# 2          NIFTY  20200101  09:17  12215.45  12216.45  12205.70  12206.80
# 3          NIFTY  20200101  09:18  12206.50  12207.40  12202.70  12202.70
# 4          NIFTY  20200101  09:19  12203.55  12208.40  12201.20  12207.85
# ...          ...       ...    ...       ...       ...       ...       ...
# 94879      NIFTY  20201231  15:28  13977.90  13981.55  13977.90  13978.45
# 94880      NIFTY  20201231  15:29  13980.20  13980.45  13966.20  13967.40
# 94881      NIFTY  20201231  15:30  13968.65  13971.10  13965.20  13967.00
# 94882      NIFTY  20201231  15:31  13967.20  13967.20  13967.20  13967.20
# 94883      NIFTY  20201231  15:32  13981.75  13981.75  13981.75  13981.75
#
#              TR      SMA5          RMA5  ...     DIPlus    DIMinus         DX  \
# 0           NaN       NaN           NaN  ...        NaN        NaN        NaN
# 1           NaN       NaN           NaN  ...        NaN        NaN        NaN
# 2           NaN       NaN           NaN  ...        NaN        NaN        NaN
# 3           NaN       NaN  12206.056923  ...        NaN        NaN        NaN
# 4           NaN  12206.92  12206.745261  ...        NaN        NaN        NaN
# ...         ...       ...           ...  ...        ...        ...        ...
# 94879  5.703571  13976.59  13977.087811  ...  17.908579  35.942392  33.488372
# 94880  6.403571  13975.06  13973.858541  ...  15.950920  41.717791  44.680851
# 94881  6.646429  13973.33  13971.572361  ...  15.368082  40.462117  44.947064
# 94882  6.414286  13971.64  13970.114907  ...  15.924276  40.089087  43.141153
# 94883  6.735714  13972.36  13973.993271  ...  30.593849  29.003181   2.669039
#
#              ADX  CenterOfLinearity  LongSignal  ShortSignal  Supertrend  \
# 0            NaN             -425.5       False        False         1.0
# 1            NaN             -425.5       False        False         1.0
# 2            NaN             -425.5       False        False         1.0
# 3            NaN             -425.5       False        False         1.0
# 4            NaN             -425.5       False        False         1.0
# ...          ...                ...         ...          ...         ...
# 94879  39.260942             -425.5        True        False         1.0
# 94880  41.505312             -425.5       False         True         1.0
# 94881  43.838969             -425.5       False         True         1.0
# 94882  46.392775             -425.5       False         True         1.0
# 94883  45.258276             -425.5        True        False         1.0
#
#        BuySignal  SellSignal
# 0          False       False
# 1          False       False
# 2          False       False
# 3          False       False
# 4          False       False
# ...          ...         ...
# 94879      False       False
# 94880      False       False
# 94881      False       False
# 94882      False       False
# 94883      False       False
#
# [94884 rows x 32 columns]

# %%
print(data['Supertrend'].value_counts()[1.0])
# Out:
# 45516

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
data['Close'].plot()
# Out:
# <Axes: >

# %%
def convert_to_hour(df):
    NoOfDays = df['Date'].nunique()
    i=0
    size = int(df.shape[0])
    newdf = pd.DataFrame({'Date' : [],'Time':[],'Open' : [],'High' : [],'Low': [], 'Close' : []})
    while i < size:
        j=0
        open  = df['Open'][i]  
        day   = df['Date'][i]
        time= df['Time'][i]
        close=0
        while(j<60 and i+j<size):
            if(df['Date'][i+j] != df['Date'][i]):
                break
            close = df['Close'][i+j]
            high = 0
            low = 100000
            if(low > df['Low'][i + j]):
                low = df['Low'][i +j]
            if(high < df['High'][i+j]):
                high= df['High'][i+j]
            j+=1
        new_record = pd.DataFrame([{'Date' : day,'Time':time,'Open' : open, 'High' : high, 'Low' : low, 'Close' : close}])
        newdf = pd.concat([newdf,new_record],ignore_index=True)
        i+=j
    return newdf

# %%
def convert_to_day(df):
    NoOfDays = df['Date'].nunique()
    newdf = pd.DataFrame({'Date' : [],'Open' : [],'High' : [],'Low': [], 'Close' : []})
    i = 0
    size = int(df.shape[0])
    while i < size:
        # newdf.columns = ['Date','Open','High','Low','Close']
        day   = df['Date'][i]
        count = df['Date'].value_counts()[day]
        open  = df['Open'][i]  
        close = df['Close'][count +i - 1]
        high = 0
        low = 100000
        for j in range(count):
            if(low > df['Low'][i+ j]):
                low = df['Low'][i + j]
            if(high < df['High'][i+j]):
                high= df['High'][i+j]
        i = i + count
        new_record = pd.DataFrame([{'Date' : day,'Open' : open, 'High' : high, 'Low' : low, 'Close' : close}])
        newdf = pd.concat([newdf,new_record],ignore_index=True)
    return newdf

# %%
def convert_to_5_min(df):
    NoOzfDays = df['Date'].nunique()
    newdf = pd.DataFrame({'Date' : [],'Start 5': [],'Open' : [],'High' : [],'Low': [], 'Close' : []})
    i = 0
    size = int(df.shape[0])
    while i < size:
        # newdf.columns = ['Date','Open','High','Low','Close']
        count = 0
        starttime = df['Time'][i]
        day   = df['Date'][i]
        if(i >= (size - 5)):
            count = size - i
        elif df['Date'][i] == df['Date'][i+5]:
            count = 5
        else:
            j = i
            while df['Date'][i] == df['Date'][j] and count < 5:
                count+=1
                j+=1
        open  = df['Open'][i]  
        close = df['Close'][count +i - 1]
        high = 0
        low = 100000
        for j in range(count):
            if(i+j >=size):
                break
            if(low > df['Low'][i+ j]):
                low = df['Low'][i + j]
                high= df['High'][i+j]
        i = i + count
        new_record = pd.DataFrame([{'Date' : day,'Start 5': starttime,'Open' : open, 'High' : high, 'Low' : low, 'Close' : close}])
        newdf = pd.concat([newdf,new_record],ignore_index=True)
    return newdf

# %%
def convert_to_15_min(df):
    NoOzfDays = df['Date'].nunique()
    newdf = pd.DataFrame({'Date' : [],'Start 15': [],'Open' : [],'High' : [],'Low': [], 'Close' : []})
    i = 0
    size = int(df.shape[0])
    while i < size:
        # newdf.columns = ['Date','Open','High','Low','Close']
        count = 0
        starttime = df['Time'][i]
        day   = df['Date'][i]
        if(i >= (size - 15)):
            count = size - i
        elif df['Date'][i] == df['Date'][i+15]:
            count = 15
        else:
            j = i
            while df['Date'][i] == df['Date'][j] and count < 15:
                count+=1
                j+=1
        open  = df['Open'][i]  
        close = df['Close'][count +i - 1]
        high = 0
        low = 100000
        for j in range(count):
            if(i+j >=size):
                break
            if(low > df['Low'][i+ j]):
                low = df['Low'][i + j]
                high= df['High'][i+j]
        i = i + count
        new_record = pd.DataFrame([{'Date' : day,'Start 15': starttime,'Open' : open, 'High' : high, 'Low' : low, 'Close' : close}])
        newdf = pd.concat([newdf,new_record],ignore_index=True)
    return newdf

# %%
def MAcrossover(df):
    short_ma = df["Close"].rolling(window=20).mean()
    long_ma = df["Close"].rolling(window=50).mean()
    # print(short_ma.to_string())
    # print(long_ma)
    trading_opportunities = []
    for i in range(len(df) - 2):
        if short_ma[i] < long_ma[i] and short_ma[i + 1] > long_ma[i + 1]:
            trading_opportunities.append(i + 1)
    profitable_trades = []
    for i in trading_opportunities:
        for j in range(0, min(10, len(df) - i)):
            if df["Close"][i + j] >= 1.02*df["Close"][i]:
                profitable_trades.append(i)
                break
    print("Number of profitable trades:", len(profitable_trades))
    print("Number of total trades:", len(trading_opportunities))

# %%
def STmaCross(df):
    ST = Supertrend(df["Supertrend"])
    long_ma = df["Close"].rolling(window=20).mean()
    # print(short_ma.to_string())
    # print(long_ma)
    trading_opportunities = []
    for i in range(len(df) - 2):
        if ST[i] < long_ma[i] and ST[i+1] > long_ma[i + 1]:
            trading_opportunities.append(i + 1)
    profitable_trades = []
    for i in trading_opportunities:
        for j in range(0, min(10, len(df) - i)):
            if df["Close"][i + j] >= 1.02*df["Close"][i]:
                profitable_trades.append(i)
                break
    print("Number of profitable trades:", len(profitable_trades))
    print("Number of total trades:", len(trading_opportunities))

# %%
def ST(df):
    ST = df["BuySignal"]
    # print(short_ma.to_string())
    # print(long_ma)
    trading_opportunities = []
    for i in range(len(df) - 2):
        if ST[i]==True:
            trading_opportunities.append(i)
    profitable_trades = []
    trades=[]
    for i in trading_opportunities:
        price=0
        for j in range(i, len(df)):
            if df["SellSignal"][j]==True:
                trades.append(df['Close'][j]-df['Close'][i])
                profitable_trades.append(price-df['Close'][i])
                break
            price=max(price,df['Close'][j])
    
    print(len(profitable_trades))
    print("Number of total trades:", len(trading_opportunities))
    return profitable_trades,trades

# %%
print(newdf['BuySignal'].value_counts()[True])
# Out:
# 142

# %%
newdf
# Out:
#              Date Start 5      Open      High       Low     Close         TR  \
# 0      20200101.0   09:08  12202.15  12208.40  12201.20  12207.85        NaN
# 1      20200101.0   09:20  12208.35  12213.20  12207.70  12217.15        NaN
# 2      20200101.0   09:25  12218.20  12215.70  12211.35  12217.30        NaN
# 3      20200101.0   09:30  12216.90  12222.20  12216.80  12218.00        NaN
# 4      20200101.0   09:35  12218.65  12210.45  12205.50  12209.05        NaN
# ...           ...     ...       ...       ...       ...       ...        ...
# 19058  20201231.0   15:10  13993.25  13991.15  13985.80  13988.85  11.132143
# 19059  20201231.0   15:15  13989.80  13984.35  13974.30  13982.25  11.703571
# 19060  20201231.0   15:20  13982.45  13985.65  13967.75  13975.05  11.992857
# 19061  20201231.0   15:25  13974.20  13980.45  13966.20  13967.40  11.389286
# 19062  20201231.0   15:30  13968.65  13971.10  13965.20  13981.75  11.003571
#
#        Supertrend  BuySignal  SellSignal
# 0             1.0      False       False
# 1             1.0      False       False
# 2             1.0      False       False
# 3             1.0      False       False
# 4             1.0      False       False
# ...           ...        ...         ...
# 19058         1.0      False       False
# 19059         1.0      False       False
# 19060         1.0      False       False
# 19061         1.0      False       False
# 19062         1.0      False       False
#
# [19063 rows x 10 columns]

# %%
profits,trades=ST(newdf)
plt.plot(profits)
# Out:
# 141
# Number of total trades: 142

# %%
plt.plot(trades)

# %%
data['SMA20']=sma(data['Close'], 20)
data['SMA50']=sma(data['Close'], 50)

# %%
plt.plot(data['Close'])
plt.plot(data['SMA20'])
plt.plot(data['SMA50'])

# %%
newdf=convert_to_5_min(data)

# %%
data.shape[0]
# Out:
# 94884

# %%
newdf.shape
# Out:
# (19063, 6)

# %%
plt.plot(newdf['Close'])

# %%
newdf
# Out:
#              Date Start 5      Open      High       Low     Close
# 0      20200101.0   09:08  12202.15  12208.40  12201.20  12207.85
# 1      20200101.0   09:20  12208.35  12213.20  12207.70  12217.15
# 2      20200101.0   09:25  12218.20  12215.70  12211.35  12217.30
# 3      20200101.0   09:30  12216.90  12222.20  12216.80  12218.00
# 4      20200101.0   09:35  12218.65  12210.45  12205.50  12209.05
# ...           ...     ...       ...       ...       ...       ...
# 19058  20201231.0   15:10  13993.25  13991.15  13985.80  13988.85
# 19059  20201231.0   15:15  13989.80  13984.35  13974.30  13982.25
# 19060  20201231.0   15:20  13982.45  13985.65  13967.75  13975.05
# 19061  20201231.0   15:25  13974.20  13980.45  13966.20  13967.40
# 19062  20201231.0   15:30  13968.65  13971.10  13965.20  13981.75
#
# [19063 rows x 6 columns]

# %%
newdf['TR'] = ATR(newdf['High'], newdf['Low'], newdf['Close'], 14)
newdf['Supertrend'],newdf['BuySignal'], newdf['SellSignal'] = Supertrend(newdf)

# %%
newdf
# Out:
#              Date Start 5      Open      High       Low     Close         TR  \
# 0      20200101.0   09:08  12202.15  12208.40  12201.20  12207.85        NaN
# 1      20200101.0   09:20  12208.35  12213.20  12207.70  12217.15        NaN
# 2      20200101.0   09:25  12218.20  12215.70  12211.35  12217.30        NaN
# 3      20200101.0   09:30  12216.90  12222.20  12216.80  12218.00        NaN
# 4      20200101.0   09:35  12218.65  12210.45  12205.50  12209.05        NaN
# ...           ...     ...       ...       ...       ...       ...        ...
# 19058  20201231.0   15:10  13993.25  13991.15  13985.80  13988.85  11.132143
# 19059  20201231.0   15:15  13989.80  13984.35  13974.30  13982.25  11.703571
# 19060  20201231.0   15:20  13982.45  13985.65  13967.75  13975.05  11.992857
# 19061  20201231.0   15:25  13974.20  13980.45  13966.20  13967.40  11.389286
# 19062  20201231.0   15:30  13968.65  13971.10  13965.20  13981.75  11.003571
#
#        Supertrend  BuySignal  SellSignal
# 0             1.0      False       False
# 1             1.0      False       False
# 2             1.0      False       False
# 3             1.0      False       False
# 4             1.0      False       False
# ...           ...        ...         ...
# 19058         1.0      False       False
# 19059         1.0      False       False
# 19060         1.0      False       False
# 19061         1.0      False       False
# 19062         1.0      False       False
#
# [19063 rows x 10 columns]

# %%
newdf['High']
# Out:
# 0        12208.40
# 1        12213.20
# 2        12215.70
# 3        12222.20
# 4        12210.45
#            ...
# 19058    13991.15
# 19059    13984.35
# 19060    13985.65
# 19061    13980.45
# 19062    13971.10
# Name: High, Length: 19063, dtype: float64

# %%
STmaCross(newdf)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[223], line 1
# ----> 1 STmaCross(newdf)
#
# Cell In[222], line 2, in STmaCross(df)
#       1 def STmaCross(df):
# ----> 2     ST = Supertrend(df["Close"])[trend]
#       3     long_ma = df["Close"].rolling(window=20).mean()
#       4     # print(short_ma.to_string())
#       5     # print(long_ma)
#
# Cell In[182], line 2, in Supertrend(data, periods, multiplier)
#       1 def Supertrend(data, periods=10, multiplier=3.0):
# ----> 2     src = (data['High'] + data['Low']) / 2
#       3     atr2 = sma(data['TR'], periods)
#       5     def nz(x, y):
#
# File ~/anaconda3/envs/ev/lib/python3.9/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/anaconda3/envs/ev/lib/python3.9/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/anaconda3/envs/ev/lib/python3.9/site-packages/pandas/core/indexes/range.py:395, in RangeIndex.get_loc(self, key, method, tolerance)
#     393             raise KeyError(key) from err
#     394     self._check_indexing_error(key)
# --> 395     raise KeyError(key)
#     396 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'High'

# %%
MAcrossover(newdf)
# Out:
# Number of profitable trades: 1
# Number of total trades: 199

# %%
MAcrossover(convert_to_5_min(data))
# Out:
# Number of profitable trades: 1
# Number of total trades: 199

# %%
print(daily.Date[92])
print(daily.Close[92])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[207], line 1
# ----> 1 print(daily.Date[92])
#       2 print(daily.Close[92])
#
# NameError: name 'daily' is not defined

# %%
print(short_ma)
